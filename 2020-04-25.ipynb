# %% [markdown]
# ## Normal (Gaussian) Distribution

# %%
dnorm
# Out:
# function (x, mean = 0, sd = 1, log = FALSE)
# .Call(C_dnorm, x, mean, sd, log)
# <bytecode: 0x7ffe2fccedf0>
# <environment: namespace:stats>

# %%
curve(dnorm())

# %%
?df

# %%
curve(df(x,df1=2, df2=20),0.12)
# Out:
# plot without title

# %%
qf(0.95, )

# %% [markdown]
# # 6장

# %%
library("Ecdat")
# Out:
# Warning message:
# “package ‘Ecdat’ was built under R version 3.5.2”Loading required package: Ecfun
# Warning message:
# “package ‘Ecfun’ was built under R version 3.5.2”Error: package or namespace load failed for ‘Ecfun’ in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]):
#  there is no package called ‘robustbase’
# Error: package ‘Ecfun’ could not be loaded
# Traceback:
#
# 1. library("Ecdat")
# 2. .getRequiredPackages2(pkgInfo, quietly = quietly)
# 3. stop(gettextf("package %s could not be loaded", sQuote(pkg)),
#  .     call. = FALSE, domain = NA)

# %%
data(Housing, package="Ecdat")
summary(lm(log(price)~log(lotsize),data=Housing))
# Out:
# Call:
# lm(formula = log(price) ~ log(lotsize), data = Housing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.85737 -0.19866  0.00396  0.19377  0.89756
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   6.46853    0.27674   23.37   <2e-16 ***
# log(lotsize)  0.54218    0.03265   16.61   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3033 on 544 degrees of freedom
# Multiple R-squared:  0.3364,	Adjusted R-squared:  0.3352
# F-statistic: 275.8 on 1 and 544 DF,  p-value: < 2.2e-16

# %%
ols = lm(log(price)~log(lotsize),data=Housing)
confint(ols)
# Out:
#              2.5 %     97.5 %
# (Intercept)  5.9249197 7.0121434
# log(lotsize) 0.4780432 0.6063147

# %%
confint(ols, 'log(lotsize)',0.95)
# Out:
# Error in confint(ols, "log(lotsize)", 0.95): 객체 'ols'를 찾을 수 없습니다
# Traceback:
#
# 1. confint(ols, "log(lotsize)", 0.95)

# %%
data(Housing, package="Ecdat")
summary(lm(I(log(price)-log(lotsize))~log(lotsize), data=Housing))
# Out:
# Call:
# lm(formula = I(log(price) - log(lotsize)) ~ log(lotsize), data = Housing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.85737 -0.19866  0.00396  0.19377  0.89756
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   6.46853    0.27674   23.37   <2e-16 ***
# log(lotsize) -0.45782    0.03265  -14.02   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3033 on 544 degrees of freedom
# Multiple R-squared:  0.2655,	Adjusted R-squared:  0.2641
# F-statistic: 196.6 on 1 and 544 DF,  p-value: < 2.2e-16

# %%
ols1 = lm((comm~age), data=Housing)
summary(ols1)
# Out:
# Error in eval(predvars, data, env): 객체 'comm'를 찾을 수 없습니다
# Traceback:
#
# 1. lm((comm ~ age), data = Housing)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = (comm ~ age), data = Housing, drop.unused.levels = TRUE)
# 5. model.frame.default(formula = (comm ~ age), data = Housing, drop.unused.levels = TRUE)
# 6. eval(predvars, data, env)
# 7. eval(predvars, data, env)

# %%
datadir = "http://econ.korea.ac.kr/~chirokhan/book/data/"

# %%
 saveRDS(저장할데이터명, "파일경로/저장할파일명.RDS")

저장한 RDS 파일을 불러올 때는 readRDS("파일경로/저장한파일명.RDS")

# %%
setwd(getwd())

# %%
saveRDS(df, "http://econ.korea.ac.kr/~chirokhan/book/data/klosasubset.rds")
# Out:
# Warning message in gzfile(file, mode):
# “압축된 파일 'http://econ.korea.ac.kr/~chirokhan/book/data/klosasubset.rds'를 열 수 없습니다.  그 이유는 아마도 'No such file or directory'입니다”
# Error in gzfile(file, mode): 커넥션을 열 수 없습니다
# Traceback:
#
# 1. saveRDS(df, "http://econ.korea.ac.kr/~chirokhan/book/data/klosasubset.rds")
# 2. gzfile(file, mode)

# %%
saveRDS(df, file.path(datadir), "klosasubset.rds")
# Out:
# Warning message in gzfile(file, mode):
# “압축된 파일 'http://econ.korea.ac.kr/~chirokhan/book/data/'를 열 수 없습니다.  그 이유는 아마도 'No such file or directory'입니다”
# Error in gzfile(file, mode): 커넥션을 열 수 없습니다
# Traceback:
#
# 1. saveRDS(df, file.path(datadir), "klosasubset.rds")
# 2. gzfile(file, mode)

# %%
saveRDS

# %%
klosa = readRDS("klosasubset.rds")

# %%
klosa
# Out:
#      pid   year male educ age married childnum hsize region     htype     ⋯
# 1     11   4    0     9   79  0       4        1     big city   dwelling  ⋯
# 2     41   4    0     0   76  1       3        2     big city   dwelling  ⋯
# 3     91   4    0     0   93  0       3        1     big city   dwelling  ⋯
# 4    101   4    0     0   75  0       3        1     big city   dwelling  ⋯
# 5    151   4    1    16   69  1       2        2     big city   dwelling  ⋯
# 6    191   4    0     6   54  0       3        3     big city   dwelling  ⋯
# 7    201   4    1     6   77  1       4        3     big city   dwelling  ⋯
# 8    211   4    1     6   83  1       6        2     big city   dwelling  ⋯
# 9    221   4    0     0   92  0       4        1     big city   dwelling  ⋯
# 10   231   4    0     0   78  0       0        1     big city   dwelling  ⋯
# 11   241   4    1    12   84  1       3        4     big city   dwelling  ⋯
# ...

# %%
ols2 = lm(satisfy5~married, data=klosa, subset=working==0 & age>=65)

# %%
ols2
# Out:
# Call:
# lm(formula = satisfy5 ~ married, data = klosa, subset = working ==
#     0 & age >= 65)
#
# Coefficients:
# (Intercept)      married
#      51.553        6.337

# %%
summary(lm(satisfy5~married, data=klosa, subset=working==0 & age>=65))
# Out:
# Call:
# lm(formula = satisfy5 ~ married, data = klosa, subset = working ==
#     0 & age >= 65)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -57.89 -11.55   2.11  12.11  48.45
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  51.5534     0.8513  60.562  < 2e-16 ***
# married       6.3365     1.1872   5.337 1.15e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 19.32 on 1058 degrees of freedom
# Multiple R-squared:  0.02622,	Adjusted R-squared:  0.0253
# F-statistic: 28.49 on 1 and 1058 DF,  p-value: 1.153e-07

# %%
names(klosa)
# Out:
#  [1] "pid"        "year"       "male"       "educ"       "age"
#  [6] "married"    "childnum"   "hsize"      "region"     "htype"
# [11] "religion"   "meeting1"   "meeting2"   "meeting3"   "meeting4"
# [16] "meeting5"   "meeting6"   "health"     "hlth"       "hlth3"
# [21] "height"     "weight"     "exercise"   "bmi"        "smoke"
# [26] "working"    "jobtype"    "jobseeking" "receive"    "give"
# [31] "poketm"     "satisfy1"   "satisfy2"   "satisfy3"   "satisfy4"
# [36] "satisfy5"   "travel1"    "travel2"    "culture1"   "culture2"
# [41] "hobby1"     "hobby2"     "training1"  "training2"  "voluntary"

# %%
ols_hlth3 = lm(satisfy5~married, data=klosa, subset=working==0 & age>=65&hlth3 >=0)

# %%
summary(ols_hlth3)
# Out:
# Call:
# lm(formula = satisfy5 ~ married, data = klosa, subset = working ==
#     0 & age >= 65 & hlth3 >= 0)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.516 -12.119   6.484   7.881  37.881
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   62.119      1.446  42.960   <2e-16 ***
# married        1.398      1.856   0.753    0.452
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.71 on 298 degrees of freedom
# Multiple R-squared:  0.001899,	Adjusted R-squared:  -0.00145
# F-statistic: 0.567 on 1 and 298 DF,  p-value: 0.4521

# %% [markdown]
# 건강 상태가 평균 이상인 사람만 고려하면 배우자 여부는 insignificant 하다

# %%
ols_hlth3_2 = lm(satisfy5~married, data=klosa, subset=working==0 & age>=65&hlth3 <0)

# %%
summary(ols_hlth3_2)
# Out:
# Call:
# lm(formula = satisfy5 ~ married, data = klosa, subset = working ==
#     0 & age >= 65 & hlth3 < 0)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -55.069 -15.069   1.587  14.931  51.587
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  48.4131     0.9911  48.849  < 2e-16 ***
# married       6.6558     1.4340   4.641 4.08e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 19.75 on 758 degrees of freedom
# Multiple R-squared:  0.02763,	Adjusted R-squared:  0.02635
# F-statistic: 21.54 on 1 and 758 DF,  p-value: 4.079e-06

# %% [markdown]
# 건강이 안좋으면 significant

# %%
ols5 = lm(satisfy5~married+hlth3, data=klosa, subset=working==0 & age>=65)
ols5
# Out:
# Call:
# lm(formula = satisfy5 ~ married + hlth3, data = klosa, subset = working ==
#     0 & age >= 65)
#
# Coefficients:
# (Intercept)      married        hlth3
#      58.695        5.091        9.480

# %%
summary(ols5)
# Out:
# Call:
# lm(formula = satisfy5 ~ married + hlth3, data = klosa, subset = working ==
#     0 & age >= 65)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -54.307 -10.358   0.784  11.825  50.784
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   58.695      1.167  50.316  < 2e-16 ***
# married        5.091      1.157   4.401 1.19e-05 ***
# hlth3          9.480      1.097   8.640  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 18.68 on 1057 degrees of freedom
# Multiple R-squared:  0.09046,	Adjusted R-squared:  0.08873
# F-statistic: 52.56 on 2 and 1057 DF,  p-value: < 2.2e-16
